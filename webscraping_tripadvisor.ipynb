# %%
url = 'https://www.tripadvisor.com/Attractions-g255060-Activities-Sydney_New_South_Wales.html#FILTERED_LIST'

# %%
from bs4 import BeautifulSoup
import requests
from requests.exceptions import ConnectionError
import json



payload = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.get('http://httpbin.org/get', params=payload)
r.encoding = 'ISO-8859-1'

HEADERS = {'user-agent': ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5)'
                          'AppleWebKit/537.36 (KHTML, like Gecko)'
                          'Chrome/45.0.2454.101 Safari/537.36'),
                          'referer': 'http://stats.nba.com/scores/'}



try:
    wd_data = requests.get(url,headers = HEADERS)
except ConnectionError:
    time.sleep(1)
    wd_data = requests.get(url,headers = HEADERS)
        
wd_data.encoding = 'ISO-8859-1'
soup = BeautifulSoup(wd_data.text,"lxml")
page_list = soup.find_all("div", {"class":"pageNumbers"})
for page in page_list:
    page = page.find_all("a")
total_page_number = int(page[-1].get('data-page-number'))
titles = soup.select("div.listing_title > a[target='_blank']")
imgs = soup.select('img[width="180"]')
cates = soup.select('div.p13n_reasoning_v2')
ratings = soup.find_all("div", {"class":"rs rating"})
types = soup.find_all("div", {"class":"p13n_reasoning_v2"})

# for item in types:
#     print(item.span.text)
attraction_rating_list = []

for title,rating in zip(titles,ratings):
    data = {
        'tourist_attraction':title.get_text(),
#         'img':img.get('src'), 
        'rating':rating.span["alt"]

    }
    attraction_rating_list.append(data)
# print(url)



urls = []
for page_number in range(total_page_number-1):
    urls.append('https://www.tripadvisor.com/Attractions-g255060-Activities-oa'+str(page_number*30 + 30)+'-Sydney_New_South_Wales.html#FILTERED_LIST')
for url in urls:
    try:
        wd_data = requests.get(url,headers = HEADERS)
    except ConnectionError:
        time.sleep(1)
        wd_data = requests.get(url,headers = HEADERS)
        
    wd_data.encoding = 'ISO-8859-1'
    soup = BeautifulSoup(wd_data.text,"lxml")
    
    titles = soup.select("div.listing_title > a[target='_blank']")
#     imgs = soup.select('img[width="180"]')
    cates = soup.select('div.p13n_reasoning_v2')
    ratings = soup.find_all("div", {"class":"rs rating"})
#     types = soup.find_all("div", {"class":"p13n_reasoning_v2"})
    
#     for element in soup.find_all("div", {"class":"rs rating"}):
#     print(element.span["alt"])

    
    for title,rating in zip(titles,ratings):
        data = {
            'tourist_attraction':title.get_text(), 
#             'img':img.get('src'), 
            'rating':rating.span["alt"]
#             'type':item.span.text
        }
        attraction_rating_list.append(data)

# %%
ratings = soup.find_all("div", {"class":"rs rating"})
for rating in ratings:
    print(rating.span['alt'])

# %%
tourist_attraction_list1 = []
rating_list = []
for i in attraction_rating_list:
    tourist_attraction_list1.append(i['tourist_attraction'])
    rating_list.append(i['rating'])
rating_list_df = pd.DataFrame(rating_list,columns =['ratings'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-61b9c88fb0dc> in <module>()
#       4     tourist_attraction_list1.append(i['tourist_attraction'])
#       5     rating_list.append(i['rating'])
# ----> 6 rating_list_df = pd.DataFrame(rating_list,columns =['ratings'])
#
# NameError: name 'pd' is not defined

# %%
from bs4 import BeautifulSoup
import requests
from requests.exceptions import ConnectionError
import pandas as pd



payload = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.get('http://httpbin.org/get', params=payload)
r.encoding = 'ISO-8859-1'

HEADERS = {'user-agent': ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5)'
                          'AppleWebKit/537.36 (KHTML, like Gecko)'
                          'Chrome/45.0.2454.101 Safari/537.36'),
                          'referer': 'http://stats.nba.com/scores/'}



try:
    wd_data = requests.get(url,headers = HEADERS)
except ConnectionError:
    time.sleep(1)
    wd_data = requests.get(url,headers = HEADERS)
        
wd_data.encoding = 'ISO-8859-1'
soup = BeautifulSoup(wd_data.text,"lxml")
page_list = soup.find_all("div", {"class":"pageNumbers"})
for page in page_list:
    page = page.find_all("a")
total_page_number = int(page[-1].get('data-page-number'))
titles = soup.select("div.listing_title > a[target='_blank']")
imgs = soup.select('img[width="180"]')
cates = soup.select('div.p13n_reasoning_v2')
ratings = soup.find_all("div", {"class":"rs rating"})
types = soup.find_all("div", {"class":"p13n_reasoning_v2"})

# for item in types:
#     print(item.span.text)
attraction_type_list = []

for title,typ in zip(titles,types):
    try:
        t = typ.span.text
    except:
        t = None
    data = {
        'tourist_attraction':title.get_text(),
#         'img':img.get('src'), 
        'type':t


    }
    attraction_type_list.append(data)
# print(url)



urls = []
for page_number in range(total_page_number-1):
    urls.append('https://www.tripadvisor.com/Attractions-g255060-Activities-oa'+str(page_number*30 + 30)+'-Sydney_New_South_Wales.html#FILTERED_LIST')
for url in urls:
    try:
        wd_data = requests.get(url,headers = HEADERS)
    except ConnectionError:
        time.sleep(1)
        wd_data = requests.get(url,headers = HEADERS)
        
    wd_data.encoding = 'ISO-8859-1'
    soup = BeautifulSoup(wd_data.text,"lxml")
    
    titles = soup.select("div.listing_title > a[target='_blank']")
    cates = soup.select('div.p13n_reasoning_v2')
    ratings = soup.find_all("div", {"class":"rs rating"})
    types = soup.find_all("div", {"class":"p13n_reasoning_v2"})

    for title,typ in zip(titles,types):
        try:
            t = typ.span.text
        except:
            t = None
        
        
        data = {
            'tourist_attraction':title.get_text(), 
#             'img':img.get('src'), 
#             'rating':rating.span["alt"]
            'type':t

        }
        attraction_type_list.append(data)

# %%
tourist_attraction_list2 = []
type_list = []
for i in attraction_type_list:
    tourist_attraction_list2.append(i['tourist_attraction'])
    type_list.append(i['type'])
    
tourist_attraction_list_df = pd.DataFrame(tourist_attraction_list2, columns =['tourist_attraction'])
type_list_df = pd.DataFrame(type_list, columns =['types'])

# %%
temp = pd.concat([tourist_attraction_list_df, rating_list_df, type_list_df], axis=1) 
# new = pd.concat([temp,type_list_df], axis=1)
temp.to_csv("Sydney.csv", index=False)

# %%
import requests
from bs4 import BeautifulSoup
url = "https://www.expedia.com/Flights-Search?flight-type=on&starDate=04%2F27%2F2018&_xpid=11905%7C1&mode=search&trip=oneway&leg1=from%3ATempe%2Cto%3AChicago%2Cdeparture%3A04%2F27%2F2018TANYT&passengers=children%3A0%2Cadults%3A1%2Cseniors%3A0%2Cinfantinlap%3AY"

r = requests.get(url);
soup = BeautifulSoup(r.content, "html5lib")

soup.find_all("a")
g_data = soup.find_all("div", {"class": "grid-container standard-padding"})

# %%
import requests

from bs4 import BeautifulSoup
url = "https://www.expedia.com/Flights-Search?flight-type=on&starDate=04%2F27%2F2018&_xpid=11905%7C1&mode=search&trip=oneway&leg1=from%3ATempe%2Cto%3AChicago%2Cdeparture%3A04%2F27%2F2018TANYT&passengers=children%3A0%2Cadults%3A1%2Cseniors%3A0%2Cinfantinlap%3AY"

r = requests.get(url);
soup = BeautifulSoup(r.content, "html5lib")

soup.find_all("a")
g_data = soup.find_all("div", {"class": "grid-container standard-padding"})

lis = []

for item in g_data:
    temp_data = soup.find_all("span", {"data-test-id": "departure-time"})
    for i in temp_data:
        lis.append(i.text)
#     for i in range(len(temp_data)):
#         lis.append(temp_data[0].text)
    break
print(lis)
# Out:
# ['11:53pm', '6:51pm', '5:15am', '7:00am', '12:10pm']

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.expedia.com/Flights-Search?trip=oneway&leg1=from%3ATokyo%2C%20Japan%20(TYO)%2Cto%3AChicago%2C%20United%20States%20of%20America%20(CHI)%2Cdeparture%3A07%2F29%2F2018TANYT&passengers=adults%3A1%2Cchildren%3A0%2Cseniors%3A0%2Cinfantinlap%3AY&options=cabinclass%3Aeconomy&mode=search&origref=www.expedia.com"
r = requests.get(url);
soup = BeautifulSoup(r.content, "html5lib")

departure_lis = []
arrival_lis = []
prices_lis = []
airline_lis = []

departure_data = soup.find_all("span", {"data-test-id": "departure-time"})
arrival_data = soup.find_all("span", {"data-test-id": "arrival-time"})
prices_data = soup.find_all("span", {"class":"full-bold no-wrap"})
airline_div = soup.find_all("div", {"class": "secondary-content overflow-ellipsis inline-children"})
for i in departure_data:
    departure_lis.append(i.text)   

for i in arrival_data:
    arrival_lis.append(i.text)
    
for i in prices_data:
    prices_lis.append(i.text)
        
for i in airline_div:
    airline_lis.append(i.text.lstrip().rstrip())


print(departure_lis)
print(arrival_lis)
print(prices_lis)
print(airline_lis)
# Out:
# ['11:15am', '6:10am', '1:50pm', '1:20pm', '9:00am']
# ['7:25am', '6:20pm', '6:20pm', '6:20pm', '6:20pm']
# ['$918', '$945', '$945', '$945', '$945']
# ['Air India', 'Asiana Airlines', 'Asiana Airlines', 'Asiana Airlines', 'Asiana Airlines']

# %%
from bs4 import BeautifulSoup
import requests
from requests.exceptions import ConnectionError
import re

def main_func(original_city, target_city, date):
    payload = {'key1': 'value1', 'key2': ['value2', 'value3']}
    r = requests.get('http://httpbin.org/get', params=payload)
    r.encoding = 'ISO-8859-1'

    HEADERS = {'user-agent': ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5)'
                              'AppleWebKit/537.36 (KHTML, like Gecko)'
                              'Chrome/45.0.2454.101 Safari/537.36'),
                              'referer': 'http://stats.nba.com/scores/'}

    url = "https://www.expedia.com/Flights-Search?trip=oneway&leg1=from:tempe,to:chicago,departure:11/30/2018TANYT&passengers=adults:1,children:0,seniors:0,infantinlap:Y&options=cabinclass:economy&mode=search&origref=www.expedia.com"
    try:
        r = requests.get(url,headers = HEADERS)
    except ConnectionError:
        time.sleep(1)
        r = requests.get(url,headers = HEADERS)
            
    soup = BeautifulSoup(r.content, "html.parser")

    departure_lis = []
    arrival_lis = []
    prices_lis = []
    airline_lis = []
    stop_lis = []

    departure_data = soup.find_all("span", attrs= {"data-test-id": "departure-time"})
    arrival_data = soup.find_all("span", attrs= {"data-test-id": "arrival-time"})
    prices_data = soup.find_all("span", attrs= {"class":"full-bold no-wrap"})
    airline_div = soup.find_all("div", attrs= {"class": "secondary-content overflow-ellipsis inline-children"})
    stop_div = soup.find_all("div", attrs= {"class":"uitk-col tablet-col-1-2 desktop-col-1-2 all-col-fill"})

    for i in departure_data:
        departure_lis.append(i.text)   

    for i in arrival_data:
        arrival_lis.append(i.text)
        
    for i in prices_data:
        prices_lis.append(i.text)
            
    for i in airline_div:
        airline_lis.append(i.text.lstrip().rstrip())
        
    for i in stop_div:
        stop_lis.append(i.find("span").text.lstrip().rstrip())

    print(departure_lis)
    print(arrival_lis)
    print(prices_lis)
    print(airline_lis)

    print(stop_lis)

# if __name__ == "__main__":
main_func('chicago', 'tempe', 233)
# Out:
# ['8:25am', '3:15pm', '12:27pm', '12:42am', '9:14am']
# ['12:47pm', '7:37pm', '4:50pm', '5:07am', '1:41pm']
# ['$171', '$171', '$171', '$171', '$171']
# ['United', 'United', 'United', 'United', 'United']
# ['3h 22m', '3h 22m', '3h 23m', '3h 25m', '3h 27m']

# %%
https://www.expedia.com/Flights-Search?trip=oneway&leg1=from:tempe,to:chicago,departure:11/30/2018TANYT&passengers=adults:1,children:0,seniors:0,infantinlap:Y&options=cabinclass:economy&mode=search&origref=www.expedia.com

# %%
import json

data = {"name": "Jane", "age": 17}

with open('friends.json', 'w') as f:
    
    json.dump(data, f)

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.expedia.com/Flights-Search?trip=oneway&leg1=from:tempe,to:chicago,departure:11/30/2018TANYT&passengers=adults:1,children:0,seniors:0,infantinlap:Y&options=cabinclass:economy&mode=search&origref=www.expedia.com"
r = requests.get(url);
soup = BeautifulSoup(r.content, "html5lib")

departure_lis = []
arrival_lis = []
prices_lis = []
airline_lis = []

departure_data = soup.find_all("span", {"data-test-id": "departure-time"})
arrival_data = soup.find_all("span", {"data-test-id": "arrival-time"})
prices_data = soup.find_all("span", {"class":"full-bold no-wrap"})
airline_div = soup.find_all("div", {"class": "secondary-content overflow-ellipsis inline-children"})
for i in departure_data:
    departure_lis.append(i.text)   

for i in arrival_data:
    arrival_lis.append(i.text)
    
for i in prices_data:
    prices_lis.append(i.text)
        
for i in airline_div:
    airline_lis.append(i.text.lstrip().rstrip())

# print(prices_data)

attraction_rating_list = []
for d_time,a_time, p in zip(departure_lis, arrival_lis, prices_lis):
    aaaaa = {
        'departure_time' : d_time,
        'arrival_time': a_time,
        'price' : p

    }
#     print(aaaaa)
    attraction_rating_list.append(aaaaa)
print(attraction_rating_list)
# Out:
# [{'departure_time': '8:25am', 'arrival_time': '12:47pm', 'price': '$171'}, {'departure_time': '3:15pm', 'arrival_time': '7:37pm', 'price': '$171'}, {'departure_time': '12:27pm', 'arrival_time': '4:50pm', 'price': '$171'}, {'departure_time': '12:42am', 'arrival_time': '5:07am', 'price': '$171'}, {'departure_time': '9:14am', 'arrival_time': '1:41pm', 'price': '$171'}]

# %%
data=[{"departure_time": "12:35am", "arrival_time": "5:55am", "stop": "3h 20m", "airline": "American Airlines", "price": "$151"}, {"departure_time": "6:50pm", "arrival_time": "12:15am", "stop": "3h 25m", "airline": "American Airlines", "price": "$151"}, {"departure_time": "5:15am", "arrival_time": "10:43am", "stop": "3h 28m", "airline": "American Airlines", "price": "$151"}, {"departure_time": "3:29pm", "arrival_time": "9:00pm", "stop": "3h 31m", "airline": "American Airlines", "price": "$151"}, {"departure_time": "1:48pm", "arrival_time": "7:25pm", "stop": "3h 37m", "airline": "American Airlines", "price": "$151"}]
for item in data:
    print(data[0]["price"][1:])
# Out:
# 151
# 151
# 151
# 151
# 151

# %%
import sys
from bs4 import BeautifulSoup
import requests
from requests.exceptions import ConnectionError
import re
import json

attraction_rating_list = []
def main_func(original_city, target_city, date):
    year = date.split('-')[0]
    month = date.split('-')[1]
    day = date.split('-')[2]
    
    payload = {'key1': 'value1', 'key2': ['value2', 'value3']}
    r = requests.get('http://httpbin.org/get', params=payload)
    r.encoding = 'ISO-8859-1'

    HEADERS = {'user-agent': ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5)'
                              'AppleWebKit/537.36 (KHTML, like Gecko)'
                              'Chrome/45.0.2454.101 Safari/537.36'),
                              'referer': 'http://stats.nba.com/scores/'}

    url = "https://www.expedia.com/Flights-Search?trip=oneway&leg1=from%3A{0}%2Cto%3A{1}%2Cdeparture%3A{2}%2F{3}%2F{4}TANYT&passengers=adults%3A1%2Cchildren%3A0%2Cseniors%3A0%2Cinfantinlap%3AY&options=cabinclass%3Aeconomy&mode=search&origref=www.expedia.com".format(original_city, target_city, month, day, year)
    # print(url)
    try:
        r = requests.get(url,headers = HEADERS)
    except ConnectionError:
        time.sleep(1)
        r = requests.get(url,headers = HEADERS)
            
    soup = BeautifulSoup(r.content, "html.parser")

    departure_lis = []
    arrival_lis = []
    prices_lis = []
    airline_lis = []
    stop_lis = []

    departure_data = soup.find_all("span", attrs= {"data-test-id": "departure-time"})
    arrival_data = soup.find_all("span", attrs= {"data-test-id": "arrival-time"})
    prices_data = soup.find_all("span", attrs= {"class":"full-bold no-wrap"})
    airline_div = soup.find_all("div", attrs= {"class": "secondary-content overflow-ellipsis inline-children"})
    stop_div = soup.find_all("div", attrs= {"class":"uitk-col tablet-col-1-2 desktop-col-1-2 all-col-fill"})

    for i in departure_data:
        departure_lis.append(i.text)   

    for i in arrival_data:
        arrival_lis.append(i.text)
        
    for i in prices_data:
        prices_lis.append(i.text)
            
    for i in airline_div:
        airline_lis.append(i.text.lstrip().rstrip())
        
    for i in stop_div:
        stop_lis.append(i.find("span").text.lstrip().rstrip())

    # print(departure_lis)
    # print(arrival_lis)
    # print(prices_lis)
    # print(airline_lis)
    # print(stop_lis)
    attraction_rating_list = []
    for d_time,a_time, p, a, s in zip(departure_lis, arrival_lis, prices_lis, airline_lis, stop_lis):
        aaaaa = {
            'departure_time' : d_time,
            'arrival_time': a_time,
            'price' : int(p[1:]),
            'airline' : a,
            'stop' : s
    
        }
        attraction_rating_list.append(aaaaa)
        print(attraction_rating_list)

        
# if __name__ == "__main__":
main_func("tempe", "chicago", "2018-06-01")
# Out:
# [{'departure_time': '12:35am', 'arrival_time': '5:55am', 'price': 151, 'airline': 'American Airlines', 'stop': '3h 20m'}]
# [{'departure_time': '12:35am', 'arrival_time': '5:55am', 'price': 151, 'airline': 'American Airlines', 'stop': '3h 20m'}, {'departure_time': '6:50pm', 'arrival_time': '12:15am', 'price': 151, 'airline': 'American Airlines', 'stop': '3h 25m'}]
# [{'departure_time': '12:35am', 'arrival_time': '5:55am', 'price': 151, 'airline': 'American Airlines', 'stop': '3h 20m'}, {'departure_time': '6:50pm', 'arrival_time': '12:15am', 'price': 151, 'airline': 'American Airlines', 'stop': '3h 25m'}, {'departure_time': '5:15am', 'arrival_time': '10:43am', 'price': 151, 'airline': 'American Airlines', 'stop': '3h 28m'}]
# ...

# %%
a = [{"departure_time": "12:35am", "arrival_time": "5:55am", "stop": "3h 20m", "airline": "American Airlines", "price": "$151"}, {"departure_time": "6:50pm", "arrival_time": "12:15am", "stop": "3h 25m", "airline": "American Airlines", "price": "$151"}, {"departure_time": "5:15am", "arrival_time": "10:43am", "stop": "3h 28m", "airline": "American Airlines", "price": "$151"}, {"departure_time": "3:29pm", "arrival_time": "9:00pm", "stop": "3h 31m", "airline": "American Airlines", "price": "$151"}, {"departure_time": "1:48pm", "arrival_time": "7:25pm", "stop": "3h 37m", "airline": "American Airlines", "price": "$151"}]

# %%
data = [] 
temp=0;

for i in a:
    print(i["price"])

# for elem in a:
#     data[temp] = elem["price"]
#     temp = temp+1
# print(data)
# Out:
# $151
# $151
# $151
# $151
# $151

# %%
import urllib.request as request
import urllib.parse as parse
import string
import re
import os
import urllib.error as error
import urllib.request as urllib2



from bs4 import BeautifulSoup
import requests
from requests.exceptions import ConnectionError
import json



payload = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.get('http://httpbin.org/get', params=payload)
r.encoding = 'ISO-8859-1'

HEADERS = {'user-agent': ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5)'
                          'AppleWebKit/537.36 (KHTML, like Gecko)'
                          'Chrome/45.0.2454.101 Safari/537.36'),
                          'referer': 'http://stats.nba.com/scores/'}




def tripadvisor(url):
    count=0
    n = urllib2.Request(url, headers=HEADERS)
    m = request.urlopen(n).read()
    
    dirpath = '/Users/shuogong/Desktop/webscraping/'
    dirname = 'untitled folder2'
    new_path = os.path.join(dirpath, dirname)
    if not os.path.isdir(new_path):
        os.makedirs(new_path)
    page_data = m.decode('gbk','ignore')
#     print (page_data)



    page_image = re.compile('\"(https://media-cdn.tripadvisor.com/media/photo-f/.+?.jpg)\"')
    for image in page_image.findall(page_data):
        pattern = re.compile(r'^https://.*.jpg$')
        print (image)
#         if  pattern.match(image):
#             print (image)
#             try:
#                 image_data = request.urlopen(image).read()
#                 image_path = dirpath + dirname +'/'+str(count)+'.jpg'
#                 count += 1
# #                 print(image_path)
#                 with open(image_path, 'wb') as image_file:
#                     image_file.write(image_data)
#                     image_file.close()
#             except error.URLError as e:
#                 print('Download failed')
#         print(image)
if __name__ == "__main__":
#     url_list = []
    url = "https://www.tripadvisor.com/Attractions-g35805-Activities-Chicago_Illinois.html"
#     url_list.append(url)


#     for page_number in range(total_page_number-1):
#         url_list.append('https://www.tripadvisor.com/Attractions-g35805-Activities-oa'+str(page_number*30 + 30)+'-Chicago_Illinois.html#FILTERED_LIST')
#     for url in url_list:  
        tripadvisor(url)
# Out:
# https://media-cdn.tripadvisor.com/media/photo-f/0d/80/3d/4d/getlstd-property-photo.jpg
# https://media-cdn.tripadvisor.com/media/photo-f/12/69/c3/bb/escape-artistry-the-railcar.jpg
# https://media-cdn.tripadvisor.com/media/photo-f/12/69/c3/bb/escape-artistry-the-railcar.jpg
# https://media-cdn.tripadvisor.com/media/photo-f/04/1b/d4/f7/art-institute-of-chicago.jpg
# https://media-cdn.tripadvisor.com/media/photo-f/06/83/80/0e/millennium-park.jpg
# https://media-cdn.tripadvisor.com/media/photo-f/04/01/42/6f/caption.jpg
# https://media-cdn.tripadvisor.com/media/photo-f/12/af/cc/ac/tulips-on-the-magnificent.jpg
# https://media-cdn.tripadvisor.com/media/photo-f/02/1e/23/8f/the-light-court.jpg
# https://media-cdn.tripadvisor.com/media/photo-f/02/36/cb/a7/the-james-charnley-house.jpg
# https://media-cdn.tripadvisor.com/media/photo-f/06/34/63/ae/emil-bach-house-by-frank.jpg
# https://media-cdn.tripadvisor.com/media/photo-f/0b/cd/3e/40/photo1jpg.jpg
# ...

# %%
from bs4 import BeautifulSoup
import requests
from requests.exceptions import ConnectionError
import json



payload = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.get('http://httpbin.org/get', params=payload)
r.encoding = 'ISO-8859-1'

HEADERS = {'user-agent': ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5)'
                          'AppleWebKit/537.36 (KHTML, like Gecko)'
                          'Chrome/45.0.2454.101 Safari/537.36'),
                          'referer': 'http://stats.nba.com/scores/'}
url = "https://www.tripadvisor.com/Attractions-g35805-Activities-Chicago_Illinois.html#FILTERED_LIST"

try:
    wd_data = requests.get(url,headers = HEADERS)
except ConnectionError:
    time.sleep(1)
    wd_data = requests.get(url,headers = HEADERS)
    
img_list = []
wd_data.encoding = 'ISO-8859-1'
soup = BeautifulSoup(wd_data.text,"lxml")
page_list = soup.find_all("div", {"class":"pageNumbers"})
for page in page_list:
    page = page.find_all("a")
total_page_number = int(page[-1].get('data-page-number'))
# titles = soup.select("div.listing_title > a[target='_blank']")
# imgs = soup.select('img[width="180"]')
# cates = soup.select('div.p13n_reasoning_v2')
# ratings = soup.find_all("div", {"class":"rs rating"})
# types = soup.find_all("div", {"class":"p13n_reasoning_v2"})

imgs = soup.find_all('div', {'class':'photo_booking non_generic'})
img_list.append(imgs)


# for item in types:
#     print(item.span.text)
# attraction_rating_list = []

# for title,rating in zip(titles,ratings):
#     data = {
#         'tourist_attraction':title.get_text(),
# #         'img':img.get('src'), 
#         'rating':rating.span["alt"]

#     }
#     attraction_rating_list.append(data)
# # print(url)



urls = []
for page_number in range(total_page_number-1):
    urls.append('https://www.tripadvisor.com/Attractions-g35805-Activities-oa'+str(page_number*30 + 30)+'-Chicago_Illinois.html#FILTERED_LIST')
for url in urls:
    try:
        wd_data = requests.get(url,headers = HEADERS)
    except ConnectionError:
        time.sleep(1)
        wd_data = requests.get(url,headers = HEADERS)
        
    wd_data.encoding = 'ISO-8859-1'
    soup = BeautifulSoup(wd_data.text,"lxml")
    
    
    imgs = soup.find_all('div', {'class':'photo_booking non_generic'})
    img_list.append(imgs)

# %%
for img in img_list:
    print(img[0])
# Out:
# <div class="photo_booking non_generic">
# <a class="photo_link " data-navarea-linktype="Thumbnail" href="/Attraction_Review-g35805-d103239-Reviews-The_Art_Institute_of_Chicago-Chicago_Illinois.html" onclick="ta.setEvtCookie('Attraction_List_Click', 'POI_click', 'photo', 1, '/Attraction_Review')" target="_blank">
# <img alt="The Art Institute of Chicago" class="photo_image" height="180" id="lazyload_152303390_11" src="https://static.tacdn.com/img2/x.gif" style="height: 180px; width: 268px; margin-left: -44px;" width="180"/>
# </a>
# ...

# %%
j = [[{"price": 107, "stop": "3h 33m", "arrival_time": "5:53am", "departure_time": "12:20am", "airline": "Frontier Airlines"}, {"price": 151, "stop": "3h 23m", "arrival_time": "5:58am", "departure_time": "12:35am", "airline": "American Airlines"}, {"price": 151, "stop": "3h 30m", "arrival_time": "10:45am", "departure_time": "5:15am", "airline": "American Airlines"}, {"price": 151, "stop": "3h 32m", "arrival_time": "12:32pm", "departure_time": "7:00am", "airline": "American Airlines"}, {"price": 159, "stop": "5h 36m", "arrival_time": "2:31pm", "departure_time": "6:55am", "airline": "Delta"}], [{"price": 104, "stop": "3h 22m", "arrival_time": "12:13am", "departure_time": "6:51pm", "airline": "American Airlines"}, {"price": 104, "stop": "3h 39m", "arrival_time": "4:19pm", "departure_time": "10:40am", "airline": "American Airlines"}, {"price": 205, "stop": "6h 0m", "arrival_time": "8:50am", "departure_time": "12:50am", "airline": "Spirit Airlines"}, {"price": 361, "stop": "3h 17m", "arrival_time": "5:52am", "departure_time": "12:35am", "airline": "American Airlines"}, {"price": 361, "stop": "3h 18m", "arrival_time": "5:11am", "departure_time": "11:53pm", "airline": "United"}], [{"price": 109, "stop": "3h 33m", "arrival_time": "5:53am", "departure_time": "12:20am", "airline": "Frontier Airlines"}, {"price": 132, "stop": "5h 51m", "arrival_time": "8:36am", "departure_time": "12:45am", "airline": "Delta"}, {"price": 132, "stop": "7h 36m", "arrival_time": "10:21am", "departure_time": "12:45am", "airline": "Delta"}, {"price": 151, "stop": "3h 19m", "arrival_time": "4:54am", "departure_time": "11:35pm", "airline": "United"}, {"price": 151, "stop": "3h 23m", "arrival_time": "5:58am", "departure_time": "12:35am", "airline": "American Airlines"}], [{"price": 107, "stop": "3h 33m", "arrival_time": "5:53am", "departure_time": "12:20am", "airline": "Frontier Airlines"}, {"price": 151, "stop": "3h 19m", "arrival_time": "4:54am", "departure_time": "11:35pm", "airline": "United"}, {"price": 151, "stop": "3h 19m", "arrival_time": "1:09pm", "departure_time": "7:50am", "airline": "United"}, {"price": 151, "stop": "3h 23m", "arrival_time": "5:58am", "departure_time": "12:35am", "airline": "American Airlines"}, {"price": 151, "stop": "3h 27m", "arrival_time": "12:22am", "departure_time": "6:55pm", "airline": "American Airlines"}], [{"price": 132, "stop": "6h 27m", "arrival_time": "7:37am", "departure_time": "11:10pm", "airline": "Delta"}, {"price": 132, "stop": "7h 26m", "arrival_time": "8:36am", "departure_time": "11:10pm", "airline": "Delta"}, {"price": 132, "stop": "7h 55m", "arrival_time": "9:05am", "departure_time": "11:10pm", "airline": "Delta"}, {"price": 151, "stop": "3h 18m", "arrival_time": "4:53am", "departure_time": "11:35pm", "airline": "United"}, {"price": 151, "stop": "3h 23m", "arrival_time": "5:58am", "departure_time": "12:35am", "airline": "American Airlines"}], [{"price": 127, "stop": "3h 33m", "arrival_time": "5:53am", "departure_time": "12:20am", "airline": "Frontier Airlines"}, {"price": 151, "stop": "3h 23m", "arrival_time": "5:58am", "departure_time": "12:35am", "airline": "American Airlines"}, {"price": 151, "stop": "3h 27m", "arrival_time": "12:22am", "departure_time": "6:55pm", "airline": "American Airlines"}, {"price": 151, "stop": "3h 30m", "arrival_time": "10:45am", "departure_time": "5:15am", "airline": "American Airlines"}, {"price": 151, "stop": "3h 32m", "arrival_time": "12:32pm", "departure_time": "7:00am", "airline": "American Airlines"}], [{"price": 132, "stop": "5h 36m", "arrival_time": "8:21am", "departure_time": "12:45am", "airline": "Delta"}, {"price": 132, "stop": "5h 51m", "arrival_time": "8:36am", "departure_time": "12:45am", "airline": "Delta"}, {"price": 132, "stop": "7h 54m", "arrival_time": "10:39am", "departure_time": "12:45am", "airline": "Delta"}, {"price": 151, "stop": "3h 19m", "arrival_time": "5:11am", "departure_time": "11:52pm", "airline": "United"}, {"price": 151, "stop": "3h 19m", "arrival_time": "1:14pm", "departure_time": "7:55am", "airline": "United"}], [{"price": 109, "stop": "3h 33m", "arrival_time": "5:53am", "departure_time": "12:20am", "airline": "Frontier Airlines"}, {"price": 151, "stop": "3h 23m", "arrival_time": "5:58am", "departure_time": "12:35am", "airline": "American Airlines"}, {"price": 151, "stop": "3h 27m", "arrival_time": "12:22am", "departure_time": "6:55pm", "airline": "American Airlines"}, {"price": 151, "stop": "3h 30m", "arrival_time": "10:45am", "departure_time": "5:15am", "airline": "American Airlines"}, {"price": 151, "stop": "3h 32m", "arrival_time": "12:32pm", "departure_time": "7:00am", "airline": "American Airlines"}], [{"price": 151, "stop": "3h 18m", "arrival_time": "4:53am", "departure_time": "11:35pm", "airline": "United"}, {"price": 151, "stop": "3h 23m", "arrival_time": "5:58am", "departure_time": "12:35am", "airline": "American Airlines"}, {"price": 151, "stop": "3h 27m", "arrival_time": "12:22am", "departure_time": "6:55pm", "airline": "American Airlines"}, {"price": 151, "stop": "3h 30m", "arrival_time": "10:45am", "departure_time": "5:15am", "airline": "American Airlines"}, {"price": 159, "stop": "5h 51m", "arrival_time": "8:36am", "departure_time": "12:45am", "airline": "Delta"}], [{"price": 109, "stop": "3h 33m", "arrival_time": "5:53am", "departure_time": "12:20am", "airline": "Frontier Airlines"}, {"price": 132, "stop": "5h 51m", "arrival_time": "8:36am", "departure_time": "12:45am", "airline": "Delta"}, {"price": 132, "stop": "7h 36m", "arrival_time": "10:21am", "departure_time": "12:45am", "airline": "Delta"}, {"price": 151, "stop": "3h 19m", "arrival_time": "4:54am", "departure_time": "11:35pm", "airline": "United"}, {"price": 151, "stop": "3h 23m", "arrival_time": "5:58am", "departure_time": "12:35am", "airline": "American Airlines"}], [{"price": 109, "stop": "3h 33m", "arrival_time": "5:53am", "departure_time": "12:20am", "airline": "Frontier Airlines"}, {"price": 151, "stop": "3h 19m", "arrival_time": "4:54am", "departure_time": "11:35pm", "airline": "United"}, {"price": 151, "stop": "3h 23m", "arrival_time": "5:58am", "departure_time": "12:35am", "airline": "American Airlines"}, {"price": 151, "stop": "3h 30m", "arrival_time": "10:45am", "departure_time": "5:15am", "airline": "American Airlines"}, {"price": 171, "stop": "3h 27m", "arrival_time": "12:22am", "departure_time": "6:55pm", "airline": "American Airlines"}]]

# %%
j[0]
# Out:
# [{'airline': 'Frontier Airlines',
#   'arrival_time': '5:53am',
#   'departure_time': '12:20am',
#   'price': 107,
#   'stop': '3h 33m'},
#  {'airline': 'American Airlines',
#   'arrival_time': '5:58am',
#   'departure_time': '12:35am',
#   'price': 151,
#   'stop': '3h 23m'},
#  {'airline': 'American Airlines',
#   'arrival_time': '10:45am',
#   'departure_time': '5:15am',
#   'price': 151,
#   'stop': '3h 30m'},
#  {'airline': 'American Airlines',
#   'arrival_time': '12:32pm',
#   'departure_time': '7:00am',
#   'price': 151,
#   'stop': '3h 32m'},
#  {'airline': 'Delta',
#   'arrival_time': '2:31pm',
#   'departure_time': '6:55am',
#   'price': 159,
#   'stop': '5h 36m'}]

# %%
https://www.expedia.com/Flights-Search?trip=oneway&leg1=from%3Atempe%2Cto%3Achicago%2Cdeparture%3A04%2F15%2018FTANYT&passengers=adults%3A1%2Cchildren%3A0%2Cseniors%3A0%2Cinfantinlap%3AY&options=cabinclass%3Aeconomy&mode=search&origref=www.expedia.com
